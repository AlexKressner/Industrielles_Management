# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexKressner/Industrielles_Management/blob/main/Bsp_Daten_laden.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Daten aus csv-Datei laden
#
#
# 1.   Repo in colab notebook klonen
# 2.   Daten mit `pandas` laden

# %%
! git clone https://github.com/AlexKressner/Industrielles_Management
# Out:
# Cloning into 'Industrielles_Management'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 44 (delta 10), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (44/44), 17.20 KiB | 8.60 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
! ls Industrielles_Management/Daten/NetworkDesign/
# Out:
# NetworkDesign_Beschaffungskosten.csv  NetworkDesign_Nachfrage.csv
# NetworkDesign_Invest_Kapa.csv	      NetworkDesign_Produktionskosten.csv

# %%
! ls Industrielles_Management/Daten/NetworkDesign/
# Out:
# NetworkDesign_Beschaffungskosten.csv  NetworkDesign_Nachfrage.csv
# NetworkDesign_Invest_Kapa.csv	      NetworkDesign_Produktionskosten.csv

# %%
# Daten laden
import pandas as pd

# %%
folder = "Industrielles_Management/Daten/NetworkDesign"

# %%
path = f"{folder}/NetworkDesign_Produktionskosten.csv"

# %%
path
# Out:
# 'Industrielles_Management/Daten/NetworkDesign/NetworkDesign_Produktionskosten.csv'

# %%
pd.read_csv()

# %%
produktionskosten=pd.read_csv(path, sep=";")

# %%
produktionskosten
# Out:
#    Produktionsstandort       Markt  Produktionskosten
# 0           Charleston         USA                 81
# 1           Charleston  Südamerika                 92
# 2           Charleston      Europa                101
# 3           Charleston       Asien                130
# 4           Charleston      Afrika                115
# 5             Curitiba         USA                117
# 6             Curitiba  Südamerika                 77
# 7             Curitiba      Europa                108
# 8             Curitiba       Asien                 98
# 9             Curitiba      Afrika                100
# 10             Hamburg         USA                102
# 11             Hamburg  Südamerika                105
# 12             Hamburg      Europa                 95
# 13             Hamburg       Asien                119
# 14             Hamburg      Afrika                111
# 15            Quanzhou         USA                115
# ...

# %% [markdown]
# ## Beispiel zur Erstellung einer Indexmenge

# %%
I = produktionskosten["Produktionsstandort"].unique().tolist() # Menge der Produktionsstandorte

# %%
I
# Out:
# ['Charleston', 'Curitiba', 'Hamburg', 'Quanzhou', 'East London']

# %% [markdown]
# ## Beispiel zur Ableitung von Parametern

# %% [markdown]
# $c_{ij}$ = Produktions- und Logistikkosten, wenn in Standort $i$ produziert und in den Markt $j$ transportiert wird

# %%
# Herstell- und Transportkosten
produktionskosten.set_index(["Produktionsstandort","Markt"], inplace=True)

# %%
produktionskosten
# Out:
#                                 Produktionskosten
# Produktionsstandort Markt
# Charleston          USA                        81
#                     Südamerika                 92
#                     Europa                    101
#                     Asien                     130
#                     Afrika                    115
# Curitiba            USA                       117
#                     Südamerika                 77
#                     Europa                    108
#                     Asien                      98
#                     Afrika                    100
# Hamburg             USA                       102
#                     Südamerika                105
#                     Europa                     95
#                     Asien                     119
#                     Afrika                    111
# Quanzhou            USA                       115
#                     Südamerika                125
# ...

# %%
c = produktionskosten.to_dict("dict")["Produktionskosten"]

# %%
c['Hamburg', 'Europa']
# Out:
# 95
